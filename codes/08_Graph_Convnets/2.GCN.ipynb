# %% [markdown]
# # Lecture : Graph Convolutional Networks
#
# ## Lab 02 : GCNs -- Solution
#
# ### Xavier Bresson, Nian Liu
#
# Kipf, Welling, Semi-supervised classification with graph convolutional networks, 2016
# https://arxiv.org/pdf/1609.02907.pdf

# %%
# For Google Colaboratory
import sys, os
if 'google.colab' in sys.modules:
    # mount google drive
    from google.colab import drive
    drive.mount('/content/gdrive')
    path_to_file = '/content/gdrive/My Drive/CS5284_2024_codes/codes/08_Graph_Convnets'
    print(path_to_file)
    # change current path to the folder containing "path_to_file"
    os.chdir(path_to_file)
    # !pwd
    # !pip install dgl==1.0.0 # Install DGL

# %%
# Libraries
import dgl
from dgl.data import MiniGCDataset
import matplotlib.pyplot as plt
import networkx as nx
import torch
from torch.utils.data import DataLoader
import torch.nn as nn
import time

# %% [markdown]
# # Visualize the artifical graph dataset used in this notebook

# %%
dataset = MiniGCDataset(8, 10, 20) # DGL artificial dataset

# visualise the 8 classes of graphs
for c in range(8):
    graph, label = dataset[c] 
    #fig, ax = plt.subplots()
    fig, ax = plt.subplots(figsize=(4,4))
    nx.draw(graph.to_networkx(), ax=ax)
    ax.set_title('Class: {:d}'.format(label))
    plt.show()

# %% [markdown]
# # Generate train, val and test datasets

# %% [markdown]
# ## Question 1: Add a node feature with the in-degree node
#
# Hints: You may use function `.in_degrees()`, `.view()`, `.float()`

# %%
# Add node features to graphs
def add_node_features(dataset):
    for (graph,_) in dataset:
        ########################################
        # YOUR CODE STARTS
        # node feature = node in-degree
        # graph.ndata['feat'].size()=(num_nodes,1) and graph.ndata['feat'].type()=torch.FloatTensor
        ########################################
        graph.ndata['feat'] = graph.in_degrees().view(-1, 1).float() # node feat is in-degree
        ########################################
        # YOUR CODE ENDS
        ########################################
    return dataset

# Generate graph datasets
trainset = MiniGCDataset(350, 10, 20)
testset = MiniGCDataset(100, 10, 20)
valset = MiniGCDataset(100, 10, 20)
trainset = add_node_features(trainset)
testset = add_node_features(testset)
valset = add_node_features(valset)
print(trainset[0])
# Out:
# (Graph(num_nodes=15, num_edges=45,
#       ndata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float32)}
#       edata_schemes={}), tensor(0))

# %% [markdown]
# ## Question 2: Define the collate function to generate a batch of DGL graphs and test it
#
# Batch a collection of DGL graphs into one graph for more efficient computation.
#
# Hints: You may use the DGL module [dgl.batch()](https://docs.dgl.ai/generated/dgl.batch.html#dgl.batch).

# %%
# collate function prepares a batch of graphs and labels 
def collate(samples):
    # Input sample is a list of pairs (graph, label)
    graphs, labels = map(list, zip(*samples)) # "graphs" is a list of "batch_size" DGL graphs
                                              # "labels" is a list of "batch_size" class labels
    ########################################
    # YOUR CODE STARTS
    # Create the DGL batch of graphs, which is equivalent to build a block diagonal matrix with all graphs in the batch
    ########################################
    batch_graphs = dgl.batch(graphs)    # batch of graphs
    ########################################
    # YOUR CODE ENDS
    ########################################
    batch_labels = torch.tensor(labels) # batch of labels
    return batch_graphs, batch_labels

# Generate a batch of graphs
batch_size = 10
train_loader = DataLoader(trainset, batch_size=batch_size, shuffle=True, collate_fn=collate)
batch_graphs, batch_labels = list(train_loader)[0]
print(batch_graphs)
print(batch_labels)
batch_x = batch_graphs.ndata['feat']
print('batch_x:',batch_x.size())
# Out:
# Graph(num_nodes=123, num_edges=621,
#       ndata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float32)}
#       edata_schemes={})
# tensor([4, 3, 5, 5, 7, 3, 7, 2, 2, 3])
# batch_x: torch.Size([123, 1])

# %% [markdown]
# ## Question 3: Design the class of GCN networks with DGL
#
# Node update equation:
# \begin{eqnarray}
# h_i^{\ell+1} &=& h_i^{\ell} + \text{ReLU} \left( \frac{1}{\sqrt{d_i}} \sum_{j\sim i} \frac{1}{\sqrt{d_j}} W^\ell h_j^{\ell} \right)
# \end{eqnarray}
#
# Instructions:
#
# Step 1: Pass node feature and edge features along edges (src/j => dst/i) in `message_func()`.
#   - `edges.src['xx']` is to pick the feature 'xx' from the source nodes of edges.
#
# Step 2: Send `reduce_func()` collects all messages={Whj, dj} to node dst/i with Step 1.
#   - `nodes.mailbox['yy']` is to gather the feature 'yy' from neighbor nodes.

# %%
# MLP layer for classification
class MLP_layer(nn.Module): 
    
    def __init__(self, input_dim, output_dim, L=2): # L = nb of hidden layers
        super(MLP_layer, self).__init__()
        list_FC_layers = [ nn.Linear( input_dim, input_dim, bias=True ) for l in range(L) ]
        list_FC_layers.append(nn.Linear( input_dim, output_dim , bias=True ))
        self.FC_layers = nn.ModuleList(list_FC_layers)
        self.L = L
        
    def forward(self, x):
        y = x
        for l in range(self.L):
            y = self.FC_layers[l](y)
            y = torch.relu(y)
        y = self.FC_layers[self.L](y)
        return y

        
# class of GatedGCN layer  
class GCN_layer(nn.Module):
    
    def __init__(self, input_dim, output_dim):
        super(GCN_layer, self).__init__()
        self.W = nn.Linear(input_dim, output_dim, bias=True)
        
    # Step 1 of message-passing with DGL: 
    #   Node feature and edge features are passed along edges (src/j => dst/i) (i.e. from all neighbours to one particular node)
    def message_func(self, edges):
        ########################################
        # YOUR CODE STARTS
        # Step 1: Pass the messages Wh_j and d_j (in-degree_j) to the node i
        ########################################
        Whj = edges.src['Wh'] 
        dj = edges.src['d'] 
        ########################################
        # YOUR CODE ENDS
        ########################################
        return {'Whj' : Whj, 'dj' : dj}

    # Step 2 of message-passing with DGL: 
    #   Reduce function collects all messages={Whj, dj} sent to node dst/i with Step 1
    def reduce_func(self, nodes):
        ########################################
        # YOUR CODE STARTS
        # Step 2: Node i receives messages Wh_j and d_j (in-degree_j) 
        ########################################
        Whj = nodes.mailbox['Whj']
        dj = nodes.mailbox['dj']
        ########################################
        # YOUR CODE ENDS
        ########################################
        inv_sqrt_dj = torch.pow(dj, -0.5) # 1/sqrt(d_j)
        h = torch.sum( inv_sqrt_dj * Whj, dim=1 ) # hi = sum_j 1/sqrt(d_j) * Bhj 
        return {'h' : h} # return update node feature hi

    def forward(self, g, h):
        h_in = h # residual connection
        g.ndata['Wh'] = self.W(h) # linear transformation of h by W!
        d = g.in_degrees().view(-1, 1).float() # in-degree d_i
        g.ndata['d'] = d
        
        g.update_all(self.message_func,self.reduce_func) # update the node feature with DGL
        
        h = g.ndata['h'] # collect the node output of graph convolution
        inv_sqrt_d = torch.pow(d, -0.5) # 1/ sqrt(d_i)
        h = inv_sqrt_d * h # h_i / sqrt(d_i)
        h = torch.relu(h) # non-linear activation
        h = h_in + h # residual connection
        return h
    
    
class GCN_net(nn.Module):
    
    def __init__(self, net_parameters):
        super(GCN_net, self).__init__()
        input_dim = net_parameters['input_dim']
        hidden_dim = net_parameters['hidden_dim']
        output_dim = net_parameters['output_dim']
        L = net_parameters['L']
        self.embedding_h = nn.Linear(input_dim, hidden_dim)
        self.GCN_layers = nn.ModuleList([ GCN_layer(hidden_dim, hidden_dim) for _ in range(L) ]) 
        self.MLP_layer = MLP_layer(hidden_dim, output_dim)
        
    def forward(self, g, h):
        # here h was the graph.ndata['feat']
        # input embedding
        h = self.embedding_h(h) # becomes (B,128)
        
        # graph convnet layers
        for GCNlayer in self.GCN_layers:
            h = GCNlayer(g,h)
        
        # MLP classifier
        g.ndata['h'] = h
        y = dgl.mean_nodes(g,'h')
        y = self.MLP_layer(y)
        
        return y    
    
    def loss(self, y_scores, y_labels):
        loss = nn.CrossEntropyLoss()(y_scores, y_labels)
        return loss        
        
    def accuracy(self, scores, targets):
        scores = scores.detach().argmax(dim=1)
        acc = (scores==targets).float().sum().item()
        return acc
    
    def update(self, lr):       
        update = torch.optim.Adam( self.parameters(), lr=lr )
        return update


# Instantiate one network (testing)
net_parameters = {}
net_parameters['input_dim'] = 1
net_parameters['hidden_dim'] = 128
net_parameters['output_dim'] = 8 # nb of classes
net_parameters['L'] = 4
net = GCN_net(net_parameters)
print(net)

def display_num_param(net):
    nb_param = 0
    for param in net.parameters():
        nb_param += param.numel()
    print('Number of parameters: {} ({:.2f} million)'.format(nb_param, nb_param/1e6))
    return nb_param/1e6
_ = display_num_param(net)
# Out:
# GCN_net(
#   (embedding_h): Linear(in_features=1, out_features=128, bias=True)
#   (GCN_layers): ModuleList(
#     (0-3): 4 x GCN_layer(
#       (W): Linear(in_features=128, out_features=128, bias=True)
#     )
#   )
#   (MLP_layer): MLP_layer(
#     (FC_layers): ModuleList(
#       (0-1): 2 x Linear(in_features=128, out_features=128, bias=True)
#       (2): Linear(in_features=128, out_features=8, bias=True)
#     )
#   )
# )
# Number of parameters: 100360 (0.10 million)

# %% [markdown]
# # Train the network

# %%
def run_one_epoch(net, data_loader, train=True):
    if train:
        net.train()
    else:
        net.eval()
    epoch_loss = 0
    epoch_acc = 0
    nb_data = 0
    gpu_mem = 0
    for iter, (batch_graphs, batch_labels) in enumerate(data_loader):
        batch_x = batch_graphs.ndata['feat']
        batch_labels = batch_labels
        batch_scores = net.forward(batch_graphs, batch_x)
        loss = net.loss(batch_scores, batch_labels)
        if train:
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        epoch_loss += loss.detach().item()
        epoch_acc += net.accuracy(batch_scores,batch_labels)
        nb_data += batch_labels.size(0)
    epoch_loss /= (iter + 1)
    epoch_acc /= nb_data
    return epoch_loss, epoch_acc 


# dataset loaders
train_loader = DataLoader(trainset, batch_size=50, shuffle=True, collate_fn=collate)
test_loader = DataLoader(testset, batch_size=50, shuffle=False, collate_fn=collate)
val_loader = DataLoader(valset, batch_size=50, shuffle=False, drop_last=False, collate_fn=collate)

# Instantiate one network
net_parameters = {}
net_parameters['input_dim'] = 1
net_parameters['hidden_dim'] = 128
net_parameters['output_dim'] = 8 # nb of classes
net_parameters['L'] = 4
net = GCN_net(net_parameters)
display_num_param(net)

# optimizer
optimizer = torch.optim.Adam(net.parameters(), lr=0.0001)

# training loop
for epoch in range(50):
    start = time.time()
    epoch_train_loss, epoch_train_acc = run_one_epoch(net, train_loader, True)
    with torch.no_grad(): 
        epoch_test_loss, epoch_test_acc = run_one_epoch(net, test_loader, False)
        epoch_val_loss, epoch_val_acc = run_one_epoch(net, val_loader, False)  
    if not epoch%2:
        print('Epoch {}, time {:.4f}, train_loss: {:.4f}, test_loss: {:.4f}, val_loss: {:.4f}'.format(epoch, time.time()-start, epoch_train_loss, epoch_test_loss, epoch_val_loss))
        print('                      train_acc: {:.4f}, test_acc: {:.4f}, val_acc: {:.4f}'.format(epoch_train_acc, epoch_test_acc, epoch_val_acc))
# Out:
# Number of parameters: 100360 (0.10 million)
# /Users/xbresson/miniconda3/envs/gnn_course/lib/python3.8/site-packages/dgl/backend/pytorch/tensor.py:445: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), (
# Epoch 0, time 0.4622, train_loss: 2.2084, test_loss: 2.0063, val_loss: 2.0063
#                       train_acc: 0.1229, test_acc: 0.1200, val_acc: 0.1200
# Epoch 2, time 1.2218, train_loss: 1.9242, test_loss: 1.9345, val_loss: 1.9345
#                       train_acc: 0.1229, test_acc: 0.1200, val_acc: 0.1200
# Epoch 4, time 0.5950, train_loss: 1.8916, test_loss: 1.8987, val_loss: 1.8987
#                       train_acc: 0.1286, test_acc: 0.1300, val_acc: 0.1300
# Epoch 6, time 0.4384, train_loss: 1.8596, test_loss: 1.8725, val_loss: 1.8725
#                       train_acc: 0.1229, test_acc: 0.1200, val_acc: 0.1200
# Epoch 8, time 0.4605, train_loss: 1.8323, test_loss: 1.8434, val_loss: 1.8434
#                       train_acc: 0.1229, test_acc: 0.1300, val_acc: 0.1300
# Epoch 10, time 0.4113, train_loss: 1.8008, test_loss: 1.8107, val_loss: 1.8107
#                       train_acc: 0.1314, test_acc: 0.1300, val_acc: 0.1300
# Epoch 12, time 0.3933, train_loss: 1.7620, test_loss: 1.7692, val_loss: 1.7692
#                       train_acc: 0.1829, test_acc: 0.2500, val_acc: 0.2500
# Epoch 14, time 0.4257, train_loss: 1.7185, test_loss: 1.7250, val_loss: 1.7250
#                       train_acc: 0.4257, test_acc: 0.4200, val_acc: 0.4200
# Epoch 16, time 0.5109, train_loss: 1.6652, test_loss: 1.6688, val_loss: 1.6688
#                       train_acc: 0.4457, test_acc: 0.4500, val_acc: 0.4500
# Epoch 18, time 0.4770, train_loss: 1.6132, test_loss: 1.6176, val_loss: 1.6176
#                       train_acc: 0.4629, test_acc: 0.5400, val_acc: 0.5400
# Epoch 20, time 0.4454, train_loss: 1.5587, test_loss: 1.5677, val_loss: 1.5677
#                       train_acc: 0.6571, test_acc: 0.6000, val_acc: 0.6000
# Epoch 22, time 0.4512, train_loss: 1.4992, test_loss: 1.5100, val_loss: 1.5100
#                       train_acc: 0.7029, test_acc: 0.6900, val_acc: 0.6900
# Epoch 24, time 0.4042, train_loss: 1.4319, test_loss: 1.4455, val_loss: 1.4455
#                       train_acc: 0.7000, test_acc: 0.6900, val_acc: 0.6900
# Epoch 26, time 0.3870, train_loss: 1.3706, test_loss: 1.3853, val_loss: 1.3853
#                       train_acc: 0.7171, test_acc: 0.7100, val_acc: 0.7100
# Epoch 28, time 0.9751, train_loss: 1.3056, test_loss: 1.3321, val_loss: 1.3321
#                       train_acc: 0.7171, test_acc: 0.6800, val_acc: 0.6800
# Epoch 30, time 0.3902, train_loss: 1.2518, test_loss: 1.2711, val_loss: 1.2711
#                       train_acc: 0.7086, test_acc: 0.6800, val_acc: 0.6800
# Epoch 32, time 0.5292, train_loss: 1.1955, test_loss: 1.2156, val_loss: 1.2156
#                       train_acc: 0.7086, test_acc: 0.6600, val_acc: 0.6600
# Epoch 34, time 0.3918, train_loss: 1.1340, test_loss: 1.1585, val_loss: 1.1585
#                       train_acc: 0.7114, test_acc: 0.7100, val_acc: 0.7100
# Epoch 36, time 0.4109, train_loss: 1.0752, test_loss: 1.1000, val_loss: 1.1000
#                       train_acc: 0.7229, test_acc: 0.6800, val_acc: 0.6800
# Epoch 38, time 0.4610, train_loss: 1.0197, test_loss: 1.0405, val_loss: 1.0405
#                       train_acc: 0.7086, test_acc: 0.6800, val_acc: 0.6800
# Epoch 40, time 0.4951, train_loss: 0.9721, test_loss: 1.0031, val_loss: 1.0031
#                       train_acc: 0.7229, test_acc: 0.6800, val_acc: 0.6800
# Epoch 42, time 0.4182, train_loss: 0.9170, test_loss: 0.9489, val_loss: 0.9489
#                       train_acc: 0.7143, test_acc: 0.7100, val_acc: 0.7100
# Epoch 44, time 0.4337, train_loss: 0.8734, test_loss: 0.9133, val_loss: 0.9133
#                       train_acc: 0.7771, test_acc: 0.7600, val_acc: 0.7600
# Epoch 46, time 0.4257, train_loss: 0.8384, test_loss: 0.8727, val_loss: 0.8727
#                       train_acc: 0.7686, test_acc: 0.7900, val_acc: 0.7900
# Epoch 48, time 0.4166, train_loss: 0.7983, test_loss: 0.8324, val_loss: 0.8324
#                       train_acc: 0.7829, test_acc: 0.7900, val_acc: 0.7900
